# %% [markdown]
# <a href="https://colab.research.google.com/github/joeyjacobs025/Emolument/blob/main/EmolumentServer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!doctype html>

<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">

  <title>Emolument</title>

</head>

<body>
  <h1>Emolument</h1>
  <div id="stocksdiv"></div>
  <script>

    async function fetchData() {

        const [data1Response, data2Response, data3Response, data4Response] = await Promise.all([
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=1'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=2'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=3'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=4'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=5'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=6'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=7'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=8'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=9'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=10'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=11'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=12'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=13'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=14'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=15'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=16'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=17'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=18'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=19'),
            fetch('https://cbaaocyalds32yjvfgnleaxdpq0cizzf.lambda-url.us-east-1.on.aws/?stockset=20')
        ]);

        const data1 = await data1Response.json();
        const data2 = await data2Response.json();
        const data3 = await data3Response.json();
        const data4 = await data4Response.json();
        const data5 = await data5Response.json();
        const data6 = await data6Response.json();
        const data7 = await data7Response.json();
        const data8 = await data8Response.json();
        const data9 = await data9Response.json();
        const data10 = await data10Response.json();
        const data11 = await data11Response.json();
        const data12 = await data12Response.json();
        const data13 = await data13Response.json();
        const data14 = await data14Response.json();
        const data15 = await data15Response.json();
        const data16 = await data16Response.json();
        const data17 = await data17Response.json();
        const data18 = await data18Response.json();
        const data19 = await data19Response.json();
        const data20 = await data20Response.json();
        return [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15, data16, data17, data18, data19, data20];
    }

    fetchData().then(([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15, data16, data17, data18, data19, data20]) => {

        // console.log(data1);
        // console.log(data2);
        // console.log(data3);
        // console.log(data4);
        // console.log(data5);
        // console.log(data6);
        // console.log(data7);
        // console.log(data8);
        // console.log(data9);
        // console.log(data10);
        // console.log(data11);
        // console.log(data12);
        // console.log(data13);
        // console.log(data14);
        // console.log(data15);
        // console.log(data16);
        // console.log(data17);
        // console.log(data18);
        // console.log(data19);
        // console.log(data20);
  
        const mergedObject = {
        ...data1,
        ...data2,
        ...data3,
        ...data4,
        ...data5,
        ...data6,
        ...data7,
        ...data8,
        ...data9,
        ...data10,
        ...data11,
        ...data12,
        ...data13,
        ...data14,
        ...data15,
        ...data16,
        ...data17,
        ...data18,
        ...data19,
        ...data20
        };

        result = Object.entries(mergedObject);
        const sortedData = result.sort((a, b) => b[1] - a[1]);
        str = '';
        sortedData.forEach(([key, value]) => str += key + ': ' + value + '</br />');
        let stocksdiv = document.getElementById('stocksdiv');
        stocksdiv.innerHTML = str;

    }).catch(error => {
        // request failed
    });

  </script>
</body>
</html>
# Out:
#   File "<ipython-input-1-f70c1ba6c9bd>", line 1
#     <!doctype html>
#     ^
# SyntaxError: invalid syntax
